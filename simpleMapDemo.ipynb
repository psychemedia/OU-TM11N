# %% [markdown]
# # Simple Embedded Map Demo
#
# Run the following cell to display the map.
#
# Click on a marker to display the popup.
#
# Click on the map to create a new marker; click on the new marker to display the latitude and longitude of that point.

# %%
#We need to import the following packages to access the maps
import folium
from folium import ClickForMarker

# %%
#Create a map centered on a particular location at a particular zoom level
mymap = folium.Map(location=[52.0236, -0.7088], zoom_start=15,
                   tiles='Stamen Terrain')

# %%
#Add two markers to the map
folium.Marker([52.0239, -0.7072], popup='OU Library').add_to(mymap)
folium.Marker([52.0242, -0.7112], popup='Jennie Lee Building').add_to(mymap)

#Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#Ceate an enhanced version of the map that lets you click on it to add a marker
mymap.add_children(ClickForMarker(None))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#EXERCISE:
#Create a map centred on you home location and add a marker to show the location of your home
